# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("CO2 Emissions_Canada.csv")
data.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
data.shape
# Out:
# (7385, 12)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1104

# %%
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# Make                                  42
# Model                               2048
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              5
# Fuel Consumption City (L/100 km)     211
# Fuel Consumption Hwy (L/100 km)      143
# Fuel Consumption Comb (L/100 km)     181
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  331
# dtype: int64

# %%
data['Vehicle Class'].unique()
# Out:
# array(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
#        'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
#        'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
#        'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL'], dtype=object)

# %%
data['Transmission'].unique()
# Out:
# array(['AS5', 'M6', 'AV7', 'AS6', 'AM6', 'A6', 'AM7', 'AV8', 'AS8', 'A7',
#        'A8', 'M7', 'A4', 'M5', 'AV', 'A5', 'AS7', 'A9', 'AS9', 'AV6',
#        'AS4', 'AM5', 'AM8', 'AM9', 'AS10', 'A10', 'AV10'], dtype=object)

# %%
data['Cylinders'].unique()
# Out:
# array([ 4,  6, 12,  8, 10,  3,  5, 16], dtype=int64)

# %%
data['Fuel Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.lineplot(data['Engine Size(L)'], data['CO2 Emissions(g/km)'])
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.lineplot(data['Fuel Consumption Comb (L/100 km)'], data['CO2 Emissions(g/km)'])
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Consumption Comb (L/100 km)', ylabel='CO2 Emissions(g/km)'>

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['Fuel Type'],data['CO2 Emissions(g/km)'])
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.boxplot(data['Fuel Type'], data['CO2 Emissions(g/km)'])
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
order = data.groupby(['Fuel Type']).mean().sort_values('CO2 Emissions(g/km)', ascending = False).index
order
# Out:
# Index(['E', 'Z', 'X', 'D', 'N'], dtype='object', name='Fuel Type')

# %%
plt.figure(dpi =200)
sns.barplot(data['Fuel Type'], data['CO2 Emissions(g/km)'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
order = data.groupby(['Transmission']).mean().sort_values ('CO2 Emissions(g/km)', ascending = False).index
plt.figure(dpi =200)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['CO2 Emissions(g/km)'],data['Transmission'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Transmission'>

# %%
order = data.groupby(['Vehicle Class']).mean().sort_values('CO2 Emissions(g/km)', ascending = False).index
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['CO2 Emissions(g/km)'],data['Vehicle Class'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Vehicle Class'>

# %%
plt.figure(dpi =200)
plt.style.use('seaborn-darkgrid')
sns.boxplot(data['CO2 Emissions(g/km)'],data['Vehicle Class'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Vehicle Class'>

# %%
order = data.groupby(['Vehicle Class']).mean().sort_values('Engine Size(L)',ascending = False). index
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['Engine Size(L)'], data['Vehicle Class'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Engine Size(L)', ylabel='Vehicle Class'>

# %%
order = data.groupby(['Transmission']).mean().sort_values('Fuel Consumption Comb (L/100 km)', ascending = False).index
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['Fuel Consumption Comb (L/100 km)'], data['Transmission'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Consumption Comb (L/100 km)', ylabel='Transmission'>

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.boxplot(data['Fuel Consumption Comb (L/100 km)'], data['Transmission'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel Consumption Comb (L/100 km)', ylabel='Transmission'>

# %%
order = data.groupby(['Make']).mean().sort_values('CO2 Emissions(g/km)', ascending = False).index
plt.figure(figsize = (6,10),dpi = 150)
plt.style.use('seaborn-darkgrid')
sns.barplot(data['CO2 Emissions(g/km)'],data['Make'], order = order)
# Out:
# C:\Users\celia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Make'>

# %%
data.corr()
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.928835
# Cylinders                               0.928835   1.000000
# Fuel Consumption City (L/100 km)        0.834209   0.801255
# Fuel Consumption Hwy (L/100 km)         0.766802   0.717627
# Fuel Consumption Comb (L/100 km)        0.820128   0.781077
# Fuel Consumption Comb (mpg)            -0.762938  -0.723710
# CO2 Emissions(g/km)                     0.854787   0.834670
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.834209
# Cylinders                                                 0.801255
# Fuel Consumption City (L/100 km)                          1.000000
# Fuel Consumption Hwy (L/100 km)                           0.950810
# Fuel Consumption Comb (L/100 km)                          0.994052
# Fuel Consumption Comb (mpg)                              -0.927637
# ...

# %%
plt.figure(dpi = 200)
plt.style.use('seaborn-darkgrid')
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
X = data[['Vehicle Class','Transmission','Fuel Type','Engine Size(L)','Cylinders','Fuel Consumption Comb (L/100 km)']]
Y = data[['CO2 Emissions(g/km)']]
X.head()
# Out:
#   Vehicle Class Transmission Fuel Type  Engine Size(L)  Cylinders  \
# 0       COMPACT          AS5         Z             2.0          4
# 1       COMPACT           M6         Z             2.4          4
# 2       COMPACT          AV7         Z             1.5          4
# 3   SUV - SMALL          AS6         Z             3.5          6
# 4   SUV - SMALL          AS6         Z             3.5          6
#
#    Fuel Consumption Comb (L/100 km)
# 0                               8.5
# 1                               9.6
# 2                               5.9
# 3                              11.1
# 4                              10.6

# %%
from sklearn.preprocessing import OrdinalEncoder
oc = OrdinalEncoder()
cols = ['Vehicle Class', 'Transmission', 'Fuel Type'] 
X[cols] = oc.fit_transform(X[cols])
# Out:
# C:\Users\celia\AppData\Local\Temp\ipykernel_1344\3030210325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[cols] = oc.fit_transform(X[cols])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
cols = ['Engine Size(L)', 'Cylinders', 'Fuel Consumption Comb (L/100 km)']
X[cols] = sc.fit_transform(X[cols])
# Out:
# C:\Users\celia\AppData\Local\Temp\ipykernel_1344\2396201383.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[cols] = sc.fit_transform(X[cols])

# %%
X.head(10)
# Out:
#    Vehicle Class  Transmission  Fuel Type  Engine Size(L)  Cylinders  \
# 0            0.0          14.0        4.0       -0.851203  -0.877058
# 1            0.0          25.0        4.0       -0.558189  -0.877058
# 2            0.0          22.0        4.0       -1.217471  -0.877058
# 3           11.0          15.0        4.0        0.247599   0.206285
# 4           11.0          15.0        4.0        0.247599   0.206285
# 5            2.0          15.0        4.0        0.247599   0.206285
# 6            2.0          15.0        4.0        0.247599   0.206285
# 7            2.0          15.0        4.0        0.394106   0.206285
# 8            2.0          25.0        4.0        0.394106   0.206285
# 9            0.0          14.0        4.0       -0.558189  -0.877058
#
#    Fuel Consumption Comb (L/100 km)
# 0                         -0.854581
# 1                         -0.481287
# 2                         -1.736911
# 3                          0.027749
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.25, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Traing set score : ', reg.score(x_train, y_train))
print('Testing set score : ', reg.score(x_test, y_test))
# Out:
# Traing set score :  0.9010088621704644
# Testing set score :  0.9088871288110215

# %%
df = pd.DataFrame()
df['Actual Values'] = y_test.values.ravel()
df['Predicted Values'] = reg.predict(x_test)
df.head(10)
# Out:
#    Actual Values  Predicted Values
# 0            232        226.970518
# 1            196        200.706463
# 2            242        254.455454
# 3            432        391.804800
# 4            205        209.911248
# 5            250        244.977787
# 6            212        213.233753
# 7            224        219.218808
# 8            301        305.624896
# 9            239        242.775193

# %%
data.groupby(['Transmission']).mean().sort_values('CO2 Emissions(g/km)', ascending = False).index
# Out:
# Index(['A7', 'A10', 'A5', 'A4', 'A8', 'AS10', 'A6', 'AS7', 'AS5', 'AM7', 'AS8',
#        'M7', 'AM9', 'AM8', 'A9', 'AS9', 'AS6', 'M6', 'AS4', 'AV8', 'M5', 'AV7',
#        'AV6', 'AM6', 'AV10', 'AV', 'AM5'],
#       dtype='object', name='Transmission')
